# %% [markdown]
# Bibliotheken

# %%
import numpy as np
from skimage.io import imread
from matplotlib import pyplot as plt
import math
import itertools

# %% [markdown]
# ##Aufgabe 1.1
# 1.Lösungsweg

# %%
img= imread('./bildverbesserung/bild1.png').astype(float)/255
#result=math.e**(img*16-10)/(1+ math.e**(img*16-10))
result=1*img**0.3
plt.imshow(result,cmap='gray',vmin=0,vmax=1)

# %% [markdown]
# ##Aufg 1.1
# 2.Lösungsweg

# %%
from skimage import exposure

img1=imread('./bildverbesserung/bild1.png')

# Enhance contrast using histogram equalization
img1_eq = exposure.equalize_hist(img1)

# Convert the image to grayscale
img1_gray = imread('./bildverbesserung/bild1.png', as_gray=True)

# Threshold the image to identify white areas
threshold = 0.9  # Adjust the threshold as needed

obscured_mask = img1_gray > threshold

# Plot the images
fig, axes = plt.subplots(1, 3, figsize=(12, 4))
axes[0].imshow(img1,cmap='gray',vmin=0,vmax=255)
axes[0].set_title('Original Image')
axes[1].imshow(img1_eq)
axes[1].set_title('Contrast Enhanced Image')
axes[2].imshow(obscured_mask, cmap='gray')
axes[2].set_title('Obscured Areas')
# Out:
# Text(0.5, 1.0, 'Obscured Areas')
